# %%
#IRIS data set - heatmap using seaborn (co-relations)

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# 1. Load the dataset
iris = load_iris()
# Create a DataFrame with the data and feature names
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# 2. Calculate the correlation matrix
# This computes the Pearson correlation between all pairs of columns
corr_matrix = df.corr()

# 3. Create the Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', cbar = False, center=0, linewidths=0.5)

# Add styling
plt.title("Correlation Heatmap of Iris Features")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# Load data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

fig, ax = plt.subplots(figsize=(8, 5))

# Draw the boxplot
sns.boxplot(data=df, ax=ax, palette="Set2")

# Set everything in one line
ax.set(
    title="Distribution of Iris Measurements",
    ylabel="Size (cm)",
    xlabel="Features",
    yticks=[0, 2, 4, 6, 8],
    xticklabels=['Sepal L', 'Sepal W', 'Petal L', 'Petal W'] # Renaming the columns for the plot
)

plt.show()
# Out:
# /tmp/ipykernel_14671/531012042.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set(
