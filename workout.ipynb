# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(6,4))
ax.plot([1,3,2], [4,5,6])
ax.set(title="hello", xticks=np.arange(0,10,1))
# Out:
# [Text(0.5, 1.0, 'hello'),
# ...

# %%
import pandas as pd
df = pd.read_csv("./datasets/titanic.csv")
df2_dict = {
    "Names" : ["Aaromal A", "Arun kumar"],
    "Marks" : [10, 20]
}
df2 = pd.DataFrame(df2_dict)
df2["Names"] = df2["Names"].str.split(" ").str[1].str.lower()
df2["endwithr"] = df["Marks".groupby()]
df2
#df2.plot(x="Names", y="Marks", marker="o")
# Out:
#    Names  Marks
# 0      a     10
# 1  kumar     20
